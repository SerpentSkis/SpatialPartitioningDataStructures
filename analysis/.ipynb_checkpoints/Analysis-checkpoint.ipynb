# %% [markdown]
# #  Analysis
# Analyze the data you collected.

# %%
# imports and setup
import seaborn

import scipy as sc
import numpy as np

import pandas as pd
import statsmodels.formula.api as sm
from sklearn import linear_model

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 6)

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %% [markdown]
# # DumbKNN change in K

# %%
kDumbKNNData = pd.read_csv('KDumbKNN.csv', index_col=0) #load data
kDumbKNNData = kDumbKNNData.transpose()
dataFrameKDumbKNNData = pd.DataFrame(data = kDumbKNNData, columns=['Time', 'K'])
dataFrameKDumbKNNData
# Out:
#        Time    K
#  1   104662   10
#  2   111050   20
#  3   113613   30
#  4   110474   40
#  5   115414   50
#  6   116863   60
#  7   117591   70
#  8   116210   80
#  9   114824   90
#  10  117150  100
#  11  121939  110
#  12  122882  120
#  13  125005  130
#  14  124454  140
#  15  123862  150
#  16  125841  160
#  17  131918  170
#  18  126200  180
#  19  131808  190
#  20  132098  200
#  21  131924  210
#  22  136883  220
#  23  133394  230
#  24  136530  240
#  25  138810  250
#  26  139722  260
#  27  132167  270
#  28  136841  280
#  29  134156  290
#  30  136899  300

# %% [markdown]
# The data are averaged over 10 iterations to reduce noise, Dim = 10. 10000 gausian training points, 100 uniform testing points.

# %%
dumbKScatterPlot = seaborn.scatterplot(data = dataFrameKDumbKNNData, x = 'K', y = 'Time')
dumbKScatterPlot.set(title='DumbKNN over k')
# Out:
# [Text(0.5, 1.0, 'DumbKNN over k')]

# %% [markdown]
# pretty linear (with noise), this makes sense. In general the change in K should be pretty linear.

# %%
result = sm.ols(formula="Time ~ K", data=dataFrameKDumbKNNData).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Time   R-squared:                       0.914
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     297.9
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           1.86e-16
# Time:                        14:46:54   Log-Likelihood:                -280.92
# No. Observations:                  30   AIC:                             565.8
# Df Residuals:                      28   BIC:                             568.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.089e+05   1093.538     99.579      0.000    1.07e+05    1.11e+05
# K            106.3203      6.160     17.260      0.000      93.703     118.938
# ==============================================================================
# Omnibus:                        1.431   Durbin-Watson:                   1.416
# Prob(Omnibus):                  0.489   Jarque-Bera (JB):                1.343
# Skew:                          -0.420   Prob(JB):                        0.511
# Kurtosis:                       2.392   Cond. No.                         364.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # DumbKNN Change in number of data points

# %%
nDumbKNNData = pd.read_csv('nDumbKNN.csv', index_col=0)
nDumbKNNData = nDumbKNNData.transpose()
dataFrameNDumbKNNData = pd.DataFrame(data = nDumbKNNData, columns=['Time', 'N'])
dataFrameNDumbKNNData
# Out:
#         Time       N
#  1     11398    1000
#  2     21736    2000
#  3     32212    3000
#  4     42422    4000
#  5     52634    5000
# ...      ...     ...
#  96   878275   96000
#  97   892171   97000
#  98   885857   98000
#  99   893417   99000
#  100  927090  100000
#
# [100 rows x 2 columns]

# %% [markdown]
# The data are averaged over 10 iterations to reduce noise. K = 10, Dim = 10. 10000 gausian training points, 100 uniform testing points.

# %%
dumbNScatterPlot = seaborn.scatterplot(data = dataFrameNDumbKNNData, x = 'N', y = 'Time')
dumbNScatterPlot.set(title='DumbKNN over N')
# Out:
# [Text(0.5, 1.0, 'DumbKNN over N')]

# %% [markdown]
# Amazing Linear, this makes sense

# %%
result = sm.ols(formula="Time ~ N", data=dataFrameNDumbKNNData).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Time   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                 5.803e+04
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):          1.05e-137
# Time:                        14:46:55   Log-Likelihood:                -1068.7
# No. Observations:                 100   AIC:                             2141.
# Df Residuals:                      98   BIC:                             2147.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.436e+04   2156.517      6.657      0.000    1.01e+04    1.86e+04
# N              8.9308      0.037    240.892      0.000       8.857       9.004
# ==============================================================================
# Omnibus:                        6.351   Durbin-Watson:                   1.130
# Prob(Omnibus):                  0.042   Jarque-Bera (JB):                5.931
# Skew:                           0.474   Prob(JB):                       0.0515
# Kurtosis:                       3.724   Cond. No.                     1.17e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.17e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # DumbKNN Change in dimension

# %%
dimensionDumbKNNData = pd.read_csv('DimensionDumbKNN.csv', index_col=0) #load data
dimensionDumbKNNData = dimensionDumbKNNData.transpose()
dataFramedimensionDumbKNNData = pd.DataFrame(data = dimensionDumbKNNData, columns=['Time', 'Dimension'])
dataFramedimensionDumbKNNData
# Out:
#        Time  Dimension
#  1    18836          1
#  2    28429          2
#  3    34947          3
#  4    43282          4
#  5    52759          5
#  6    66069          6
#  7    70725          7
#  8    86436          8
#  9    94381          9
#  10  102481         10
#  11  105232         11
#  12  119042         12
#  13  131823         13
#  14  139438         14
#  15  145755         15
#  16   94390         16
#  17  130928         17
#  18  125466         18
#  19  143615         19
#  20  150276         20
#  21  148001         21
#  22  170476         22
#  23  173370         23
#  24  225629         24
#  25  263651         25
#  26  267989         26
#  27  241639         27
#  28  261773         28
#  29  263918         29
#  30  266240         30

# %% [markdown]
# The data are averaged over 10 iterations to reduce noise. K = 10. 10000 gausian training points, 100 uniform testing points.

# %%
dumbDimScatterPlot = seaborn.scatterplot(data = dataFramedimensionDumbKNNData, x = 'Dimension', y = 'Time')
dumbDimScatterPlot.set(title='DumbKNN over Dimension')
# Out:
# [Text(0.5, 1.0, 'DumbKNN over Dimension')]

# %% [markdown]
# It is linear, but for some reason from Dimension 16 onwards it gets weird.

# %%
result = sm.ols(formula="Time ~ Dimension", data=dataFramedimensionDumbKNNData).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Time   R-squared:                       0.923
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     333.5
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           4.33e-17
# Time:                        14:46:55   Log-Likelihood:                -341.37
# No. Observations:                  30   AIC:                             686.7
# Df Residuals:                      28   BIC:                             689.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   8087.0115   8203.761      0.986      0.333   -8717.632    2.49e+04
# Dimension   8439.5390    462.107     18.263      0.000    7492.955    9386.123
# ==============================================================================
# Omnibus:                        1.263   Durbin-Watson:                   0.701
# Prob(Omnibus):                  0.532   Jarque-Bera (JB):                0.774
# Skew:                          -0.393   Prob(JB):                        0.679
# Kurtosis:                       2.985   Cond. No.                         36.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # BucketKNN change in K

# %%
kBucketKNNData = pd.read_csv('KBucketKNN.csv', index_col=0) #load data
kBucketKNNData = kBucketKNNData.transpose()
dataFrameKBucketKNN = pd.DataFrame(data = kBucketKNNData, columns=['Time', 'K'])
dataFrameKBucketKNN
# Out:
#        Time    K
#  1   131368   10
#  2   128956   20
#  3   128951   30
#  4   129237   40
#  5   131097   50
#  6   136177   60
#  7   131931   70
#  8   143482   80
#  9   144210   90
#  10  139446  100
#  11  139678  110
#  12  138651  120
#  13  136149  130
#  14  135230  140
#  15  141938  150
#  16  137554  160
#  17  137534  170
#  18  141626  180
#  19  138064  190
#  20  141983  200
#  21  144437  210
#  22  143730  220
#  23  146553  230
#  24  148127  240
#  25  150281  250
#  26  153814  260
#  27  155997  270
#  28  150822  280
#  29  156976  290
#  30  156581  300

# %% [markdown]
# The data are averaged over 10 iterations to reduce noise. K = 10, Dim = 8. 10,000 gausian training points, 100 uniform testing points.

# %%
bucketKScatterPlot = seaborn.scatterplot(data = dataFrameKBucketKNN, x = 'K', y = 'Time')
bucketKScatterPlot.set(title='BucketKNN over k')
# Out:
# [Text(0.5, 1.0, 'BucketKNN over k')]

# %% [markdown]
# somewhat linear with weird bumps.

# %%
result = sm.ols(formula="Time ~ K", data=dataFrameKBucketKNN).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Time   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.797
# Method:                 Least Squares   F-statistic:                     115.0
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           2.01e-11
# Time:                        14:46:55   Log-Likelihood:                -288.41
# No. Observations:                  30   AIC:                             580.8
# Df Residuals:                      28   BIC:                             583.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.282e+05   1403.818     91.329      0.000    1.25e+05    1.31e+05
# K             84.7967      7.908     10.724      0.000      68.599     100.995
# ==============================================================================
# Omnibus:                        2.216   Durbin-Watson:                   1.039
# Prob(Omnibus):                  0.330   Jarque-Bera (JB):                1.681
# Skew:                           0.577   Prob(JB):                        0.431
# Kurtosis:                       2.876   Cond. No.                         364.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # BucketKNN Change in number of data points

# %%
nBucketKNNData = pd.read_csv('nBucketKNN.csv', index_col=0) #load data
nBucketKNNData = nBucketKNNData.transpose()
dataFrameNBucketKNN = pd.DataFrame(data = nBucketKNNData, columns=['Time', 'N'])
dataFrameNBucketKNN
# Out:
#        Time      N
#  1     9267   1000
#  2    17702   2000
#  3    26315   3000
#  4    35457   4000
#  5    41484   5000
#  6    49356   6000
#  7    58282   7000
#  8    63360   8000
#  9    78254   9000
#  10   79340  10000
#  11   88195  11000
#  12   93162  12000
#  13  111669  13000
#  14  107208  14000
#  15  122567  15000
#  16  125112  16000
#  17  140378  17000
#  18  156756  18000
#  19  167808  19000
#  20  182988  20000
#  21  186702  21000
#  22  183546  22000
#  23  193792  23000
#  24  214152  24000
#  25  215429  25000
#  26  231524  26000
#  27  223838  27000
#  28  235891  28000
#  29  248126  29000
#  30  263503  30000
#  31  268281  31000
#  32  278065  32000
#  33  283963  33000
#  34  329679  34000
#  35  376409  35000
#  36  352296  36000
#  37  334399  37000
#  38  378440  38000
#  39  381670  39000
#  40  359613  40000
#  41  403968  41000
#  42  385721  42000
#  43  402860  43000
#  44  430086  44000
#  45  414689  45000
#  46  485871  46000
#  47  431240  47000
#  48  459259  48000
#  49  500601  49000
#  50  526763  50000

# %% [markdown]
# The data are averaged over 10 iterations to reduce noise. K = 10, Dim = 4.  gausian training points increment by 1000, 100 uniform testing points.

# %%
buccketNScatterPlot = seaborn.scatterplot(data = dataFrameNBucketKNN, x = 'N', y = 'Time')
buccketNScatterPlot.set(title='BucketKNN over N')
# Out:
# [Text(0.5, 1.0, 'BucketKNN over N')]

# %% [markdown]
# Very linear. after around 35k it gets weird but still follows the general trend. This makes sense.

# %%
result = sm.ols(formula="Time ~ N", data=dataFrameNBucketKNN).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Time   R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                     3037.
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           4.67e-45
# Time:                        14:46:55   Log-Likelihood:                -561.41
# No. Observations:                  50   AIC:                             1127.
# Df Residuals:                      48   BIC:                             1131.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.112e+04   5333.700     -3.960      0.000   -3.18e+04   -1.04e+04
# N             10.0323      0.182     55.112      0.000       9.666      10.398
# ==============================================================================
# Omnibus:                        5.953   Durbin-Watson:                   1.252
# Prob(Omnibus):                  0.051   Jarque-Bera (JB):                5.213
# Skew:                           0.782   Prob(JB):                       0.0738
# Kurtosis:                       3.236   Cond. No.                     5.95e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.95e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # BucketKNN Change in dimension

# %%
dimensionBucketKNNData = pd.read_csv('DimensionBucketKNN.csv', index_col=0) #load data
dimensionBucketKNNData = dimensionBucketKNNData.transpose()
dataFramedimensionBucketKNN = pd.DataFrame(data = dimensionBucketKNNData, columns=['Time', 'Dimension'])
dataFramedimensionBucketKNN
# Out:
#        Time  Dimension
#  1     2601          1
#  2    20862          2
#  3    62029          3
#  4    80536          4
#  5    92449          5
#  6   102067          6
#  7   133837          7
#  8   134562          8
#  9   155998          9
#  10  157978         10
#  11  173627         11
#  12  210031         12
#  13  233872         13
#  14  302961         14
#  15  476429         15

# %% [markdown]
# The data are averaged over 10 iterations to reduce noise. K = 10. 10000 gausian training points, 100 uniform testing points.

# %%
bucketDimScatterPlot = seaborn.scatterplot(data = dataFramedimensionBucketKNN, x = 'Dimension', y = 'Time')
bucketDimScatterPlot.set(title='BucketKNN over Dimension')
# Out:
# [Text(0.5, 1.0, 'BucketKNN over Dimension')]

# %% [markdown]
# seems linear for low dim, but it scales up fast near dim = 14+ which suggests exponencial which makes sense. It gets impossibly slow really fast. I couldn't get more data than this in any resonable amount of time.

# %%
result = sm.ols(formula="Time ~ Dimension", data=dataFramedimensionBucketKNN).fit()
result.summary()
# Out:
# /Users/chadhurst/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Time   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.813
# Method:                 Least Squares   F-statistic:                     61.78
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           2.71e-06
# Time:                        14:46:55   Log-Likelihood:                -182.93
# No. Observations:                  15   AIC:                             369.9
# Df Residuals:                      13   BIC:                             371.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -3.727e+04   2.79e+04     -1.334      0.205   -9.76e+04    2.31e+04
# Dimension   2.416e+04   3073.443      7.860      0.000    1.75e+04    3.08e+04
# ==============================================================================
# Omnibus:                       18.860   Durbin-Watson:                   0.767
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.269
# Skew:                           1.856   Prob(JB):                     0.000108
# Kurtosis:                       6.930   Cond. No.                         19.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # QuadTree change in K

# %%
kQuadTreeKNNData = pd.read_csv('KQuadTreeKNN.csv', index_col=0) #load data
kQuadTreeKNNData = kQuadTreeKNNData.transpose()
dataFrameKQuadTreeKNNData = pd.DataFrame(data = kQuadTreeKNNData, columns=['Time', 'K'])
dataFrameKQuadTreeKNNData
# Out:
#       Time    K
#  1    7888   10
#  2   12157   20
#  3   13274   30
#  4   17299   40
#  5   17738   50
#  6   19201   60
#  7   21342   70
#  8   21704   80
#  9   23640   90
#  10  26421  100
#  11  26323  110
#  12  27781  120
#  13  27574  130
#  14  30065  140
#  15  33333  150
#  16  35928  160
#  17  35542  170
#  18  35362  180
#  19  37495  190
#  20  37205  200
#  21  38910  210
#  22  40216  220
#  23  37590  230
#  24  38087  240
#  25  39769  250
#  26  41748  260
#  27  38723  270
#  28  35922  280
#  29  45456  290
#  30  48724  300

# %%
kQuadTreeScatterPlot = seaborn.scatterplot(data = dataFrameKQuadTreeKNNData, x = 'K', y = 'Time')
kQuadTreeScatterPlot.set(title='QuadTree over K')
# Out:
# [Text(0.5, 1.0, 'QuadTree over K')]

# %% [markdown]
# This seems to be pretty linear, which makes sense.

# %%
result = sm.ols(formula="Time ~ K", data=dataFrameKQuadTreeKNNData).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Time   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     327.6
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           5.48e-17
# Time:                        14:46:56   Log-Likelihood:                -281.66
# No. Observations:                  30   AIC:                             567.3
# Df Residuals:                      28   BIC:                             570.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    1.27e+04   1120.985     11.329      0.000    1.04e+04     1.5e+04
# K            114.2824      6.314     18.099      0.000     101.348     127.217
# ==============================================================================
# Omnibus:                        9.231   Durbin-Watson:                   0.663
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):                7.657
# Skew:                          -1.057   Prob(JB):                       0.0217
# Kurtosis:                       4.286   Cond. No.                         364.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Quad Tree change in N

# %%
nQuadTreeKNNData = pd.read_csv('nQuadTreeKNN.csv', index_col=0) #load data
nQuadTreeKNNData = nQuadTreeKNNData.transpose()
dataFrameNQuadTreeKNNData = pd.DataFrame(data = nQuadTreeKNNData, columns=['Time', 'N'])
dataFrameNQuadTreeKNNData
# Out:
#       Time      N
#  1    2213   1000
#  2    3319   2000
#  3    4208   3000
#  4    5386   4000
#  5    5632   5000
#  6    6293   6000
#  7    6680   7000
#  8    6903   8000
#  9    7354   9000
#  10   7605  10000
#  11   9038  11000
#  12   8662  12000
#  13   8611  13000
#  14   9203  14000
#  15  10057  15000
#  16   9851  16000
#  17  10423  17000
#  18  10265  18000
#  19  11149  19000
#  20  10813  20000
#  21  11743  21000
#  22  12264  22000
#  23  12878  23000
#  24  13777  24000
#  25  13994  25000
#  26  12771  26000
#  27  13497  27000
#  28  13836  28000
#  29  14402  29000
#  30  14931  30000
#  31  15220  31000
#  32  15117  32000
#  33  14804  33000
#  34  15842  34000
#  35  14938  35000
#  36  17325  36000
#  37  16639  37000
#  38  16498  38000
#  39  16534  39000
#  40  16607  40000
#  41  16881  41000
#  42  17003  42000
#  43  18345  43000
#  44  18512  44000
#  45  17256  45000
#  46  20356  46000
#  47  19355  47000
#  48  18580  48000
#  49  18317  49000
#  50  19287  50000

# %%
nQuadTreeScatterPlot = seaborn.scatterplot(data = dataFrameNQuadTreeKNNData, x = 'N', y = 'Time')
nQuadTreeScatterPlot.set(title='QuadTree over total number of data points')
# Out:
# [Text(0.5, 1.0, 'QuadTree over total number of data points')]

# %% [markdown]
# seems like it may have a log trend, but mostly linear. You would expect to see a log trend. With more data it would show up better.

# %%
result = sm.ols(formula="Time ~ N", data=dataFrameNQuadTreeKNNData).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Time   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.964
# Method:                 Least Squares   F-statistic:                     1311.
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           1.65e-36
# Time:                        14:46:56   Log-Likelihood:                -409.82
# No. Observations:                  50   AIC:                             823.6
# Df Residuals:                      48   BIC:                             827.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4516.6351    257.254     17.557      0.000    3999.392    5033.878
# N              0.3179      0.009     36.209      0.000       0.300       0.336
# ==============================================================================
# Omnibus:                        5.444   Durbin-Watson:                   0.834
# Prob(Omnibus):                  0.066   Jarque-Bera (JB):                4.344
# Skew:                          -0.671   Prob(JB):                        0.114
# Kurtosis:                       3.535   Cond. No.                     5.95e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.95e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # KDTree change in K

# %%
kKDTreeData = pd.read_csv('KKDTreeKNN.csv', index_col=0) #load data
kKDTreeData = kKDTreeData.transpose()
dataFrameKKDTreeData = pd.DataFrame(data = kKDTreeData, columns=['Time', 'K'])
dataFrameKKDTreeData
# Out:
#        Time    K
#  1   137869   10
#  2   154596   20
#  3   166068   30
#  4   172656   40
#  5   183763   50
#  6   188162   60
#  7   199155   70
#  8   205348   80
#  9   213075   90
#  10  220477  100
#  11  223942  110
#  12  227692  120
#  13  234035  130
#  14  241894  140
#  15  245880  150
#  16  252485  160
#  17  254300  170
#  18  255631  180
#  19  261006  190
#  20  270376  200
#  21  271979  210
#  22  276144  220
#  23  281773  230
#  24  286335  240
#  25  289967  250
#  26  294334  260
#  27  294066  270
#  28  302771  280
#  29  303668  290
#  30  310426  300

# %% [markdown]
# The data are averaged over 10 iterations to reduce noise. K = 10. 10000 gausian training points, 100 uniform testing points.

# %%
kKDTreeScatterPlot = seaborn.scatterplot(data = dataFrameKKDTreeData, x = 'K', y = 'Time')
kKDTreeScatterPlot.set(title='KDTree over k')
# Out:
# [Text(0.5, 1.0, 'KDTree over k')]

# %% [markdown]
# Pretty linear, with a bit of a log shape to it.

# %%
result = sm.ols(formula="Time ~ K", data=dataFrameKKDTreeData).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Time   R-squared:                       0.974
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                     1033.
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           1.20e-23
# Time:                        14:46:56   Log-Likelihood:                -311.06
# No. Observations:                  30   AIC:                             626.1
# Df Residuals:                      28   BIC:                             628.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.568e+05   2987.241     52.498      0.000    1.51e+05    1.63e+05
# K            540.8932     16.827     32.145      0.000     506.425     575.361
# ==============================================================================
# Omnibus:                        9.302   Durbin-Watson:                   0.218
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):                7.722
# Skew:                          -1.080   Prob(JB):                       0.0210
# Kurtosis:                       4.229   Cond. No.                         364.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # KDTree Change in number of data points

# %%
nKDTreeKNNData = pd.read_csv('nKDTreeKNN.csv', index_col=0) #load data
nKDTreeKNNData = nKDTreeKNNData.transpose()
dataFrameNKDTree = pd.DataFrame(data = nKDTreeKNNData, columns=['Time', 'N'])
dataFrameNKDTree
# Out:
#        Time      N
#  1    17535   1000
#  2    32800   2000
#  3    46464   3000
#  4    59003   4000
#  5    74684   5000
#  6    86820   6000
#  7    98050   7000
#  8   111288   8000
#  9   124634   9000
#  10  137521  10000
#  11  144935  11000
#  12  163808  12000
#  13  176780  13000
#  14  186704  14000
#  15  198685  15000
#  16  209026  16000
#  17  220162  17000
#  18  234208  18000
#  19  244659  19000
#  20  261289  20000
#  21  268226  21000
#  22  276641  22000
#  23  288268  23000
#  24  304573  24000
#  25  314139  25000
#  26  320909  26000
#  27  345743  27000
#  28  349588  28000
#  29  361420  29000
#  30  379247  30000
#  31  390570  31000
#  32  394327  32000
#  33  396104  33000
#  34  432887  34000
#  35  417065  35000
#  36  443467  36000
#  37  455761  37000
#  38  459200  38000
#  39  478949  39000
#  40  504230  40000
#  41  492744  41000
#  42  516620  42000
#  43  566309  43000
#  44  596753  44000
#  45  572967  45000
#  46  602736  46000
#  47  583850  47000
#  48  632457  48000
#  49  614985  49000
#  50  644397  50000

# %% [markdown]
# The data are averaged over 10 iterations to reduce noise. K = 10. 10000 gausian training points, 100 uniform testing points.

# %%
NKDTreeScatterPlot = seaborn.scatterplot(data = dataFrameNKDTree, x = 'N', y = 'Time')
NKDTreeScatterPlot.set(title='KDTree over N')
# Out:
# [Text(0.5, 1.0, 'KDTree over N')]

# %% [markdown]
# Very linear. It has a slight uptick near the end which supports the idea that it is n log(n). It gets a little noisy for higher N. You would expect n log(n), this might show up better with more data

# %%
result = sm.ols(formula="Time ~ N", data=dataFrameNKDTree).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Time   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 1.021e+04
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           1.41e-57
# Time:                        14:46:56   Log-Likelihood:                -541.78
# No. Observations:                  50   AIC:                             1088.
# Df Residuals:                      48   BIC:                             1091.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7951.7004   3602.495      2.207      0.032     708.399    1.52e+04
# N             12.4209      0.123    101.023      0.000      12.174      12.668
# ==============================================================================
# Omnibus:                       11.068   Durbin-Watson:                   1.332
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               14.211
# Skew:                           0.740   Prob(JB):                     0.000820
# Kurtosis:                       5.152   Cond. No.                     5.95e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.95e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Its not a linear relationship so this ols doesnt really work. Just look at the graph.

# %% [markdown]
# # KDTree Change in dimension

# %%
dimensionKDTreeData = pd.read_csv('DimensionKDTreeKNN.csv', index_col=0) #load data
dimensionKDTreeData = dimensionKDTreeData.transpose()
dataFrameDimensionKDTreeData = pd.DataFrame(data = dimensionKDTreeData, columns=['Time', 'Dimension'])
dataFrameDimensionKDTreeData
# Out:
#        Time  Dimension
#  1   106741          1
#  2    20387          2
#  3    17590          3
#  4    20516          4
#  5    21178          5
#  6    31093          6
#  7    43368          7
#  8    50955          8
#  9   125301          9
#  10  146216         10
#  11  179516         11
#  12  181877         12
#  13  206882         13
#  14  229929         14
#  15  246448         15
#  16  202468         16
#  17  244418         17
#  18  257640         18
#  19  304702         19
#  20  319585         20
#  21  340898         21
#  22  283988         22
#  23  407917         23
#  24  313315         24
#  25  494367         25
#  26  387415         26
#  27  546048         27
#  28  363581         28
#  29  575462         29
#  30  439508         30

# %% [markdown]
# The data are averaged over 10 iterations to reduce noise. K = 10. 10000 gausian training points, 100 uniform testing points.

# %%
kdTreeDimScatterPlot = seaborn.scatterplot(data = dimensionKDTreeData, x = 'Dimension', y = 'Time')
kdTreeDimScatterPlot.set(title='KDTreeKNN over Dimension')
# Out:
# [Text(0.5, 1.0, 'KDTreeKNN over Dimension')]

# %% [markdown]
# somewhat linear, with some wildness. After dimension 22 it gets weird.

# %%
result = sm.ols(formula="Time ~ Dimension", data=dimensionKDTreeData).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Time   R-squared:                       0.893
# Model:                            OLS   Adj. R-squared:                  0.889
# Method:                 Least Squares   F-statistic:                     234.4
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           3.90e-15
# Time:                        14:46:56   Log-Likelihood:                -368.43
# No. Observations:                  30   AIC:                             740.9
# Df Residuals:                      28   BIC:                             743.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -3.333e+04   2.02e+04     -1.648      0.110   -7.48e+04    8090.431
# Dimension   1.744e+04   1139.019     15.311      0.000    1.51e+04    1.98e+04
# ==============================================================================
# Omnibus:                        3.559   Durbin-Watson:                   2.619
# Prob(Omnibus):                  0.169   Jarque-Bera (JB):                2.555
# Skew:                           0.712   Prob(JB):                        0.279
# Kurtosis:                       3.134   Cond. No.                         36.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
